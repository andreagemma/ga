# %%
# %load_ext autoreload
# %autoreload 2
import duckdb

# %%
with EngineDuckDB.connect(file_based=False) as conn:
    df = conn.read(f"postgresql://postgres:lDvdc15dcd5@192.168.133.80:5432/m4i?table=links&schema=eur2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with EngineDuckDB.connect(file_based=False) as conn:
#       2     df = conn.read(f"postgresql://postgres:lDvdc15dcd5@192.168.133.80:5432/m4i?table=links&schema=eur2")
#
# NameError: name 'EngineDuckDB' is not defined

# %%
class A:
    def __init__(self, i:int =0):
        self.i = i
        pass

    def unionByName(self: "A", right: "A"):
        return self.i + right.i
    

a = A(1)
b = A(2)
print(a.unionByName(b))
print(A.unionByName(a, b))
# Out:
# 3
# 3

# %%
import importlib.util

if importlib.util.find_spec("ipywidgets") is None:
    print("ipywidgets mancante")
else:
    print("ipywidgets installato")
# Out:
# ipywidgets mancante
